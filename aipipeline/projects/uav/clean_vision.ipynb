# %%
# Visualize UAV labeled images to determine correct filtering parameters to remove bad images
# Note - for classification only, not for detection

# %%
crop_base_path = "/Users/dcline/Dropbox/data/UAV/crops/crops/"

# %%
import os
from cleanvision import Imagelab
crop_path = os.path.join(crop_base_path, "Kelp")
imagelab = Imagelab(crop_path)
imagelab.find_issues(issue_types={"low_information":{"threshold": 0.53}})
# Out:
# Reading images from /Users/dcline/Dropbox/data/UAV/crops/crops/Kelp
# Checking for low_information images ...
# 100%|██████████| 18383/18383 [00:13<00:00, 1354.84it/s]
# Issue checks completed. 146 issues found in the dataset. To see a detailed report of issues found, use imagelab.report().

# %%
imagelab.report(num_images=20)
# Out:
# Issues found in images in order of severity in the dataset
#
# |    | issue_type      |   num_images |
# |---:|:----------------|-------------:|
# |  0 | low_information |          146 |
#
# ------------------ low_information images ------------------
#
# Number of examples with this issue: 146
# Examples representing most severe instances of this issue:

# %%
imagelab.issues
# Out:
#                                                     low_information_score  \
# /Users/dcline/Dropbox/data/UAV/crops/crops/Kelp...               0.647636
# /Users/dcline/Dropbox/data/UAV/crops/crops/Kelp...               0.808744
# /Users/dcline/Dropbox/data/UAV/crops/crops/Kelp...               0.799239
# /Users/dcline/Dropbox/data/UAV/crops/crops/Kelp...               0.728179
# /Users/dcline/Dropbox/data/UAV/crops/crops/Kelp...               0.752233
# ...                                                                   ...
# /Users/dcline/Dropbox/data/UAV/crops/crops/Kelp...               0.681831
# /Users/dcline/Dropbox/data/UAV/crops/crops/Kelp...               0.652737
# /Users/dcline/Dropbox/data/UAV/crops/crops/Kelp...               0.699295
# /Users/dcline/Dropbox/data/UAV/crops/crops/Kelp...               0.564490
# /Users/dcline/Dropbox/data/UAV/crops/crops/Kelp...               0.625431
#
#                                                     is_low_information_issue
# ...

# %%
crop_path = os.path.join(crop_base_path, "Poop")
imagelab = Imagelab(crop_path)
imagelab.find_issues(issue_types={"low_information":{"threshold": 0.53}})
# Out:
# Reading images from /Users/dcline/Dropbox/data/UAV/crops/crops/Poop
# Checking for low_information images ...
# 100%|██████████| 5347/5347 [00:03<00:00, 1433.87it/s]
# Issue checks completed. 415 issues found in the dataset. To see a detailed report of issues found, use imagelab.report().

# %%
imagelab.report(num_images=20)
# Out:
# Issues found in images in order of severity in the dataset
#
# |    | issue_type      |   num_images |
# |---:|:----------------|-------------:|
# |  0 | low_information |          415 |
#
# ------------------ low_information images ------------------
#
# Number of examples with this issue: 415
# Examples representing most severe instances of this issue:

# %%
crop_path = os.path.join(crop_base_path, "Jelly")
imagelab = Imagelab(crop_path)
imagelab.find_issues(issue_types={"low_information":{"threshold": 0.53}})
# Out:
# Reading images from /Users/dcline/Dropbox/data/UAV/crops/crops/Jelly
# Checking for low_information images ...
# 100%|██████████| 349/349 [00:01<00:00, 254.19it/s]
# Issue checks completed. 0 issues found in the dataset. To see a detailed report of issues found, use imagelab.report().

# %%
crop_path = os.path.join(crop_base_path, "Bird")
imagelab = Imagelab(crop_path)
imagelab.find_issues(issue_types={"low_information":{"threshold": 0.53}})
# Out:
# Reading images from /Users/dcline/Dropbox/data/UAV/crops/crops/Bird
# Checking for low_information images ...
# 100%|██████████| 4095/4095 [00:02<00:00, 1418.06it/s]
# Issue checks completed. 4 issues found in the dataset. To see a detailed report of issues found, use imagelab.report().

# %%
imagelab.report()
# Out:
# Issues found in images in order of severity in the dataset
#
# |    | issue_type      |   num_images |
# |---:|:----------------|-------------:|
# |  0 | low_information |            4 |
#
# ------------------ low_information images ------------------
#
# Number of examples with this issue: 4
# Examples representing most severe instances of this issue:

# %%
crop_path = os.path.join(crop_base_path, "Whale")
imagelab = Imagelab(crop_path)
imagelab.find_issues(issue_types={"low_information":{"threshold": 0.53}})
# Out:
# Reading images from /Users/dcline/Dropbox/data/UAV/crops/crops/Whale
# Checking for low_information images ...
# 100%|██████████| 1/1 [00:00<00:00,  2.30it/s]
# Issue checks completed. 0 issues found in the dataset. To see a detailed report of issues found, use imagelab.report().

# %%
crop_path = os.path.join(crop_base_path, "Batray")
imagelab = Imagelab(crop_path)
imagelab.find_issues(issue_types={"low_information":{"threshold": 0.53}})
# Out:
# Reading images from /Users/dcline/Dropbox/data/UAV/crops/crops/Batray
# Checking for low_information images ...
# 100%|██████████| 231/231 [00:01<00:00, 194.57it/s]
# Issue checks completed. 10 issues found in the dataset. To see a detailed report of issues found, use imagelab.report().

# %%
imagelab.report(num_images=10)
# Out:
# Issues found in images in order of severity in the dataset
#
# |    | issue_type      |   num_images |
# |---:|:----------------|-------------:|
# |  0 | low_information |           10 |
#
# ------------------ low_information images ------------------
#
# Number of examples with this issue: 10
# Examples representing most severe instances of this issue:
